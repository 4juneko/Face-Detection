# %% [markdown]
# https://github.com/serengil/retinaface
# https://github.com/sglee487/Pytorch_Retinaface

# %% [markdown]
# # prepare

# %%
# !git clone https://github.com/sglee487/Pytorch_Retinaface.git
# Out:
# fatal: destination path 'Pytorch_Retinaface' already exists and is not an empty directory.

# %%
pip install retina-face

# %%
from retinaface import RetinaFace

# %%
image_path = 'C:/Users/pc3/Desktop/unidentify_10000ea/KAMO/ident_image/rear/1681710996530154943.png'
resp = RetinaFace.detect_faces(image_path)

# %%
for i, (key, value) in enumerate(resp.items()):
#     print(f'Index: {i}, Key: {key}, Value: {value}')
    print(key, resp[key]['facial_area'])
    for i in resp[key]['facial_area']:
        print(i)
len(resp.items())
# resp 가 딕셔너리
# Out:
# face_1 [655, 213, 689, 252]
# 655
# 213
# 689
# 252
# face_2 [380, 200, 427, 251]
# 380
# 200
# 427
# 251
# face_3 [763, 224, 795, 264]
# 763
# 224
# 795
# 264
# face_4 [941, 189, 975, 229]
# 941
# 189
# 975
# 229
# face_5 [434, 209, 463, 249]
# 434
# 209
# 463
# 249
# face_6 [825, 492, 876, 557]
# 825
# 492
# 876
# 557
# 6

# %%
import numpy as np
import cv2
import os

# %%
 # 인식된 얼굴에 대한 후속 처리
image = cv2.imread(image_path)
height, width, channels = image.shape
print(image.shape)
# Out:
# (720, 1280, 3)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 6
#       3 height, width, channels = image.shape
#       4 print(image.shape)
# ----> 6 np_array = np.array([tensor.np() for tensor in resp])
#       7 np_array
#
# Cell In[46], line 6, in <listcomp>(.0)
#       3 height, width, channels = image.shape
#       4 print(image.shape)
# ----> 6 np_array = np.array([tensor.np() for tensor in resp])
#       7 np_array
#
# AttributeError: 'str' object has no attribute 'np'

# %%
boxes =[]
blur_img = cv2.GaussianBlur(image ,(99,99), 30)
indexes = len(resp.items())
for i, (key, value) in enumerate(resp.items()):
#    print(key, resp[key]['facial_area'])
    detection = resp[key]['facial_area']
    x = int(detection[0])
    y = int(detection[1])
    w = int(detection[2])
    h = int(detection[3])
#    print(x,y,w,h)
    boxes.append([x, y, w, h])

for i in range(indexes):
    if i in range(len(boxes)):
        x, y, w, h = boxes[i]
#             print(boxes[i])
        # label = f'{classes[class_ids[i]]}: {confidences[i]:.2f}'
        face_image = blur_img[y:h, x:w]
        image[y:h, x:w] = face_image

save_path = 'C:/Users/pc3/Desktop/unidentify_10000ea/' + '1682576861142292976.png'
cv2.imwrite(save_path, image)
# Out:
# True

# %%
indexes = len(resp.items())
indexes
# Out:
# 6

# %% [markdown]
# #  treat directory

# %% [markdown]
# - 함수로 진행했는데 딕셔너리가 튜플로 바뀌고 print 하니깐 안바뀌네  무슨 이유인지 알 수가 없음.
# - AttributeError: 'tuple' object has no attribute 의 에러. => 인식할 얼굴이 없어서 그렇네.. => 그냥 원본을 저장하고 YOLOv8에서 인식하면 될 거 같음.
# - 3.5시간/2500장: 시간이 오래 걸림ㅁ

# %%
#input, output 경로 정하기
input_path = 'C:/Users/pc3/Desktop/unidentify_10000ea/KAMO/ident_image/front/'
output_path = 'C:/Users/pc3/Desktop/unidentify_10000ea/KAMO_un/front_/'

# %%
file_list = os.listdir(input_path)
len(file_list)
# Out:
# 2500

# %%
for img in file_list:
    try:
        image_path = input_path + img
        resp = RetinaFace.detect_faces(image_path)
        image = cv2.imread(image_path)
        boxes=[]
     #   print(type(resp))
     #   boxes =[]

    #    np_array = np.array([tensor.numpy() for  in resp])

        indexes = int(len(resp.items()))

        for i, (key, value) in enumerate(resp.items()):
        #    print(key, resp[key]['facial_area'])
            boxes.append(resp[key]['facial_area'])


        blur_img = cv2.GaussianBlur(image ,(99,99), 30)

        for i in range(indexes):
            if i in range(len(boxes)):
                x, y, w, h = boxes[i]
        #             print(boxes[i])
                # label = f'{classes[class_ids[i]]}: {confidences[i]:.2f}'
                face_image = blur_img[y:h, x:w]
                image[y:h, x:w] = face_image

        save_path = output_path + img
        cv2.imwrite(save_path, image)

    except AttributeError:
        save_path = output_path + img
        cv2.imwrite(save_path, image)
        print(img)
        pass
# Out:
# 1681712638552733183.png
# 1681712644123428106.png
# 1681712811981556416.png
# 1681712859616799831.png
# 1681712935106319427.png
# 1681712987778739214.png
# 1681713520441466093.png
# 1681713543792164326.png
# 1681713634959794760.png
# 1681713691868566036.png
# 1681713696872276306.png
# 1681713702943562508.png
# 1681713708847918510.png
# 1681713760886723280.png
# 1681798291807543755.png
# 1681882747128217936.png
# 1681885028392030001.png
# 1681885326213748693.png
# 1681885638146087885.png
# 1681885643583475113.png
# 1682318164238518000.png

# %%
# print 있어서 더 느림.
for img in file_list:
    image_path = 'C:/Users/pc3/Desktop/unidentify_10000ea/NAVYA/ident_image/rear/'+img
    resp = RetinaFace.detect_faces(image_path)
    print(type(resp))
    boxes =[]

#    np_array = np.array([tensor.numpy() for  in resp])

    indexes = int(len(resp.items()))

    for i, (key, value) in enumerate(resp.items()):
    #    print(key, resp[key]['facial_area'])
        detection = resp[key]['facial_area']
        x = int(detection[0])
        y = int(detection[1])
        w = int(detection[2])
        h = int(detection[3])
    #    print(x,y,w,h)
        boxes.append([x, y, w, h])

    image = cv2.imread(image_path)
    blur_img = cv2.GaussianBlur(image ,(99,99), 30)


    for i in range(indexes):
        if i in range(len(boxes)):
            x, y, w, h = boxes[i]
    #             print(boxes[i])
            # label = f'{classes[class_ids[i]]}: {confidences[i]:.2f}'
            face_image = blur_img[y:h, x:w]
            image[y:h, x:w] = face_image

    save_path = 'C:/Users/pc3/Desktop/unidentify_10000ea/NAVYA_un/rear_/' + img
    cv2.imwrite(save_path, image)
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# ...

# %%
for i in file_list:
    blur(i)
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# ...

# %%
# 인식한 얼굴 crop image
import matplotlib.pyplot as plt
faces = RetinaFace.extract_faces(img_path = "/content/1681711498856820583.png", align = True)
for face in faces:
  plt.imshow(face)
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[151], line 3
#       1 # 인식한 얼굴 crop image
#       2 import matplotlib.pyplot as plt
# ----> 3 faces = RetinaFace.extract_faces(img_path = "/content/1681711498856820583.png", align = True)
#       4 for face in faces:
#       5   plt.imshow(face)
#
# File ~\anaconda3\Lib\site-packages\retinaface\RetinaFace.py:190, in extract_faces(img_path, threshold, model, align, allow_upscaling)
#     186 resp = []
#     188 #---------------------------
# --> 190 img = get_image(img_path)
#     192 #---------------------------
#     194 obj = detect_faces(img_path = img, threshold = threshold, model = model, allow_upscaling = allow_upscaling)
#
# File ~\anaconda3\Lib\site-packages\retinaface\RetinaFace.py:43, in get_image(img_path)
#      41 if type(img_path) == str:  # Load from file path
#      42     if not os.path.isfile(img_path):
# ...
